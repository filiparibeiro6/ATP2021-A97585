# %% [markdown]
# # TPC4
# **Keyname:** TPC4
#
# **Título:** Manipulação de Frações
#
# **Data de início:** 2021/11/06
#
# **Data de finalização:** 2021/11/08
#
# **Supervisor:** José Carlos Leite Ramalho, www.di.uminho.pt/~jcr/
#
# **Autor:** Filipa Alexandra Cardoso Ribeiro

# %% [markdown]
# **Resumo:** Algoritmo que com duas frações ou o número que o utilizador desejar, manualmente ou de forma aleatória, permite efetuar as seguintes operações: **soma**, **subtração**, **divisão** e **multiplicação**. Dentro deste algoritmo, retorna o valor simplificado das frações, usando a máximo divisor comum.
